# %% [markdown]
# Mart - Annual IP flows
# ======================

# %%
# !pip uninstall utils
# Out:
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\shresthn\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\shresthn\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping utils as it is not installed.

# %%
import duckdb

from utils.paths import INT_IP_FLOWS_DIR, MARTS_IP_FLOWS_DIR

# %%
int_filename   = 'int_ip_flows.parquet'
marts_filename = 'fct_ip_flows_yearly.csv.gz'

in_path  = INT_IP_FLOWS_DIR   / int_filename
out_path = MARTS_IP_FLOWS_DIR / marts_filename

# %%
con = duckdb.connect()

query = f"""
COPY (SELECT * FROM read_parquet('{in_path.as_posix()}'))
TO '{out_path.as_posix()}'
(FORMAT CSV,
 HEADER,
 DELIMITER ',',
 QUOTE '"',
 ESCAPE '"',
 NULL '',
 COMPRESSION GZIP);
"""

con.execute(query)

con.close()
