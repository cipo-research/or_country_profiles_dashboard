# %% [markdown]
# Mart: Macroecon flows (annual time-grain) fact table
# ================================

# %%
from time import sleep
from pathlib import Path 
import pandas as pd 
import sys

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))

from utils.paths import INT_MACROECON_FLOWS_DIR, MARTS_MACROECON_FLOWS_DIR

# %%
int_macroecon_flows_filename = 'int_macroecon_flows.csv'

macroecon_flows_df = pd.read_csv(INT_MACROECON_FLOWS_DIR / int_macroecon_flows_filename)

# %%
fct_macroecon_flows_filename = 'fct_macroecon_flows_yearly.csv'

macroecon_flows_df.to_csv(MARTS_MACROECON_FLOWS_DIR / fct_macroecon_flows_filename, index=False)
